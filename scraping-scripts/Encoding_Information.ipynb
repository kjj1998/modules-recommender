# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import os
import ast
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
model = SentenceTransformer('all-mpnet-base-v2')
# Out:
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
def from_np_array(array_string):
    
    if (array_string == ''):
        return []
    
    array_data = ast.literal_eval(array_string)
    return array_data

# %%
def fill_empty_course_info(row):
    course_name = row['Course Name']
    course_info = row['Course Information']
    
    if (isinstance(course_info, str) == False):
        course_info = course_name
        
    return course_info

# %%
def encode_course_info(model, row):
    course_info = row['Course Information']
    embedding = []
    
    if (isinstance(course_info, str) == False):
        return ""
    
    embeddings = model.encode(course_info)
    
    embedding_string = ""
    
    for embedding in embeddings:
        embedding_string += str(embedding) + "|"
        
    embedding_string = embedding_string[0 : len(embedding_string)-1]
            
    return embedding_string

# %%
def encode_course_name(model, row):
    course_name = row['Course Name']
    embedding = []
    
    if (isinstance(course_name, str) == False):
        return ""
    
    embeddings = model.encode(course_name)
    
    embedding_string = ""
    
    for embedding in embeddings:
        embedding_string += str(embedding) + "|"
        
    embedding_string = embedding_string[0 : len(embedding_string)-1]
            
    return embedding_string

# %%
all_modules = pd.read_csv('scraped-data/all_modules.csv')

# %%
all_modules = pd.read_csv('scraped-data/all_modules.csv', converters={'Prerequisites': from_np_array, 'Mutually Exclusive': from_np_array, 'Topics': from_np_array})

# %%
valid_courses = all_modules['Course Code'].tolist()

# %%
prerequisites_group_df = pd.DataFrame(columns=['course_code', 'prerequisites', 'group_id'])

# %%
mutually_exclusive_group_df = pd.DataFrame(columns=['course_code', 'mutually_exclusive'])

# %%
prereq_id = 0

# %%
for index, row in all_modules.iterrows():
    course_code = row['Course Code']
    list_of_mutually_exclusives = row['Mutually Exclusive']
    
    if (list_of_mutually_exclusives == None or isinstance(list_of_mutually_exclusives, float) == True or list_of_mutually_exclusives == []):
        continue
        
    for mutually_exclusive in list_of_mutually_exclusives:
        if (mutually_exclusive in valid_courses):
            new_row = pd.Series([course_code, mutually_exclusive], index=['course_code', 'mutually_exclusive'])
            mutually_exclusive_group_df = mutually_exclusive_group_df.append(new_row, ignore_index=True)

# %%
for index, row in all_modules.iterrows():
    course_code = row['Course Code']
    list_of_prerequisites = row['Prerequisites']
    course_info = row['Course Information']
    
    if (list_of_prerequisites == None or isinstance(list_of_prerequisites, float) == True or list_of_prerequisites == []):
        continue
        
    for prerequisites in list_of_prerequisites:
        piped_prerequisites = ""
        prereq_group_id = "prereq_group_" + str(prereq_id)

        for prerequisite in prerequisites:
            if (prerequisite in valid_courses):
                piped_prerequisites += prerequisite + '|'
            else:
                piped_prerequisites = ""
                break

             
        if (len(piped_prerequisites) != 0):
            piped_prerequisites = piped_prerequisites[0 : len(piped_prerequisites)-1]

            new_row = pd.Series([course_code, piped_prerequisites, prereq_group_id], index=['course_code', 'prerequisites', 'group_id'])
            prereq_id += 1

            prerequisites_group_df = prerequisites_group_df.append(new_row, ignore_index=True)

# %%
prerequisites_group_df.to_csv(os.path.join(os.getcwd(), "scraped-data/prerequisite_groups.csv"), index=False)

# %%
mutually_exclusive_group_df.to_csv(os.path.join(os.getcwd(), "scraped-data/mutually_exclusive.csv"), index=False)

# %%
all_modules.drop('Prerequisites', axis=1, inplace=True)

# %%
all_modules.drop('Mutually Exclusive', axis=1, inplace=True)

# %%
all_modules['Course Information'] = all_modules.apply(lambda row: fill_empty_course_info(row), axis=1)

# %%
all_modules['Encoded Course Information'] = all_modules.apply(lambda row: encode_course_info(model, row), axis=1)

# %%
all_modules['Encoded Course Name'] = all_modules.apply(lambda row: encode_course_name(model, row), axis=1)

# %%
all_modules.to_csv(os.path.join(os.getcwd(), "scraped-data/all_modules_with_encodings.csv"), index=False)

# %%
all_modules_with_topics = pd.read_csv('all_modules_with_topics.csv', converters={'Prerequisites': from_np_array, 'Mutually Exclusive': from_np_array, 'Topics': from_np_array})

# %%
all_modules.tail(50)
# Out:
#      Course Code                                        Course Name  \
# 1822      AED38E                          PSYCHOPATHOLOGY IN YOUTHS
# 1823      MA0303                          HUMAN RESOURCE MANAGEMENT
# 1824      MA5105                    ENGINEERING MANAGEMENT ANALYSIS
# 1825      CM5012                   INTRODUCTION TO FORENSIC SCIENCE
# 1826      CS5207                FIFTY DISCOVERIES, FIFTY INVENTIONS
# 1827      EE5087                            LIVING WITH MATHEMATICS
# 1828      DM5001                                         WEB DESIGN
# 1829      BU5241                                FINANCIAL WELLBEING
# 1830      BU5544   MARKETING HEALTH: CONSUMERS' PURSUIT OF WELLNESS
# 1831      BU5644      SMARTER BRAIN? THE SCIENCE OF DECISION MAKING
# 1832      CS5005                 THE POWER OF MEDIA: MYTH & REALITY
# 1833      CS5211                                   HOW MUSIC SPEAKS
# 1834      CY1007                                     CLIMATE CHANGE
# 1835      CY0002                                             ETHICS
# 1836      CY1602                                     MATHEMATICS II
# 1837      BL5305                                  ADVANCED TAXATION
# 1838      DA5000                                    APPLIED DRAWING
# 1839      DA5002                      WATERMEDIA LANDSCAPE PAINTING
# 1840      DA5003  KINETIC ANATOMY:DYNAMIC FIG DRAWING FOR ARTIST...
# 1841      DA5004    DESIGN, ART, & ANIMATION FOR MEDIA ARCHITECTURE
# 1842      DA5010                           FIGURE SCULPTURE IN CLAY
# 1843      DF5002                                  CINEMATOGRAPHY II
# 1844      DT5000                                  DIGITAL SCULPTING
# 1845      DT5001                               GRAPHIC STORYTELLING
# 1846      DV5002                                   PACKAGING DESIGN
# 1847      BS1033         LABORATORY FOR FOUNDATIONS OF CHEMISTRY II
# 1848      CH5200                                  FOOD MICROBIOLOGY
# 1824                   Mechanical/Aerospace Engineering
# 1825  Chemistry, Chemical Engineering and Biotechnology
# 1826                              Communication Studies
# 1827                             Electrical Engineering
# 1828                              Art, Design and Media
# 1829                               Business/Accountancy
# 1830                               Business/Accountancy
# 1831                               Business/Accountancy
# 1832                              Communication Studies
# 1833                              Communication Studies
# 1834                         CN Yang Scholars Programme
# 1835                         CN Yang Scholars Programme
# 1836                         CN Yang Scholars Programme
# 1837                               Business/Accountancy
# 1838                              Art, Design and Media
# 1839                              Art, Design and Media
# 1840                              Art, Design and Media
# 1841                              Art, Design and Media
# 1842                              Art, Design and Media
# 1843                              Art, Design and Media
# 1844                              Art, Design and Media
# 1845                              Art, Design and Media
# 1846                              Art, Design and Media
# 1847                                 Biological Science
# 1848  Chemistry, Chemical Engineering and Biotechnology
# 1849                                   Entrepreneurship
# 1850  Chemistry, Chemical Engineering and Biotechnology
# 1851  Chemistry, Chemical Engineering and Biotechnology
# 1852                          Environment Earth Systems
# 1853                                        Mathematics
# 1854                                        Mathematics
# 1855                                           Medicine
# 1856                    National Institute of Education
# 1857                    National Institute of Education
# 1858                    National Institute of Education
# 1859                    National Institute of Education
# 1860                    National Institute of Education
# 1861                    National Institute of Education
# 1862                    National Institute of Education
# 1863                    National Institute of Education
# 1864                    National Institute of Education
# 1865                    National Institute of Education
# 1866                    National Institute of Education
# 1867                    National Institute of Education
# 1868                    National Institute of Education
# 1869                    National Institute of Education
# 1870                                   Entrepreneurship
# 1871  Chemistry, Chemical Engineering and Biotechnology

# %%
valid_courses = all_modules['Course Code'].tolist()

# %%
prerequisites_group_df = pd.DataFrame(columns=['course_code', 'prerequisites', 'group_id'])

# %%
mutually_exclusive_group_df = pd.DataFrame(columns=['course_code', 'mutually_exclusive'])

# %%
prereq_id = 0

# %%
for index, row in all_modules.iterrows():
    course_code = row['Course Code']
    list_of_mutually_exclusives = row['Mutually Exclusive']
    
    if (list_of_mutually_exclusives == None or isinstance(list_of_mutually_exclusives, float) == True or list_of_mutually_exclusives == []):
        continue
        
    for mutually_exclusive in list_of_mutually_exclusives:
        if (mutually_exclusive in valid_courses):
            new_row = pd.Series([course_code, mutually_exclusive], index=['course_code', 'mutually_exclusive'])
            mutually_exclusive_group_df = mutually_exclusive_group_df.append(new_row, ignore_index=True)

# %%
for index, row in all_modules.iterrows():
    course_code = row['Course Code']
    list_of_prerequisites = row['Prerequisites']
    course_info = row['Course Information']
    
    if (list_of_prerequisites == None or isinstance(list_of_prerequisites, float) == True or list_of_prerequisites == []):
        continue
        
    for prerequisites in list_of_prerequisites:
        piped_prerequisites = ""
        prereq_group_id = "prereq_group_" + str(prereq_id)

        for prerequisite in prerequisites:
            if (prerequisite in valid_courses):
                piped_prerequisites += prerequisite + '|'
            else:
                piped_prerequisites = ""
                break

             
        if (len(piped_prerequisites) != 0):
            piped_prerequisites = piped_prerequisites[0 : len(piped_prerequisites)-1]

            new_row = pd.Series([course_code, piped_prerequisites, prereq_group_id], index=['course_code', 'prerequisites', 'group_id'])
            prereq_id += 1

            prerequisites_group_df = prerequisites_group_df.append(new_row, ignore_index=True)

# %%
prerequisites_group_df.to_csv(os.path.join(os.getcwd(), "scraped-data/prerequisite_groups.csv"), index=False)

# %%
mutually_exclusive_group_df.to_csv(os.path.join(os.getcwd(), "scraped-data/mutually_exclusive.csv"), index=False)

# %%
prereq_id = 0

# %%
for index, row in all_modules.iterrows():
    course_code = row['Course Code']
    list_of_mutually_exclusives = row['Mutually Exclusive']
    
    if (list_of_mutually_exclusives == None or isinstance(list_of_mutually_exclusives, float) == True or list_of_mutually_exclusives == []):
        continue
        
    for mutually_exclusive in list_of_mutually_exclusives:
        if (mutually_exclusive in valid_courses):
            new_row = pd.Series([course_code, mutually_exclusive], index=['course_code', 'mutually_exclusive'])
            mutually_exclusive_group_df = mutually_exclusive_group_df.append(new_row, ignore_index=True)

# %%
for index, row in all_modules.iterrows():
    course_code = row['Course Code']
    list_of_prerequisites = row['Prerequisites']
    course_info = row['Course Information']
    
    if (list_of_prerequisites == None or isinstance(list_of_prerequisites, float) == True or list_of_prerequisites == []):
        continue
        
    for prerequisites in list_of_prerequisites:
        piped_prerequisites = ""
        prereq_group_id = "prereq_group_" + str(prereq_id)

        for prerequisite in prerequisites:
            if (prerequisite in valid_courses):
                piped_prerequisites += prerequisite + '|'
            else:
                piped_prerequisites = ""
                break

             
        if (len(piped_prerequisites) != 0):
            piped_prerequisites = piped_prerequisites[0 : len(piped_prerequisites)-1]

            new_row = pd.Series([course_code, piped_prerequisites, prereq_group_id], index=['course_code', 'prerequisites', 'group_id'])
            prereq_id += 1

            prerequisites_group_df = prerequisites_group_df.append(new_row, ignore_index=True)

# %%
prerequisites_group_df.to_csv(os.path.join(os.getcwd(), "prerequisite_groups.csv"), index=False)

# %%
mutually_exclusive_group_df.to_csv(os.path.join(os.getcwd(), "mutually_exclusive.csv"), index=False)

# %%
all_modules.drop('Prerequisites', axis=1, inplace=True)

# %%
all_modules.drop('Mutually Exclusive', axis=1, inplace=True)

# %%
all_modules.to_csv(os.path.join(os.getcwd(), "scraped-data/all_modules_final.csv"), index=False)

# %%
all_modules = pd.read_csv("scraped-data/all_modules_final.csv")

# %%
all_modules['Course Information'] = all_modules.apply(lambda row: fill_empty_course_info(row), axis=1)

# %%
all_modules.to_csv(os.path.join(os.getcwd(), "all_modules_with_no_empty_course_info.csv"), index=False)

# %%
all_modules['Encoded Course Information'] = all_modules.apply(lambda row: encode_course_info(model, row), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 all_modules['Encoded Course Information'] = all_modules.apply(lambda row: encode_course_info(model, row), axis=1)
#
# File ~\Desktop\Projects\modules2Students\scraping-scripts\env\lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\Desktop\Projects\modules2Students\scraping-scripts\env\lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# File ~\Desktop\Projects\modules2Students\scraping-scripts\env\lib\site-packages\pandas\core\apply.py:891, in FrameApply.apply_standard(self)
#     890 def apply_standard(self):
# --> 891     results, res_index = self.apply_series_generator()
#     893     # wrap results
#     894     return self.wrap_results(results, res_index)
#
# File ~\Desktop\Projects\modules2Students\scraping-scripts\env\lib\site-packages\pandas\core\apply.py:907, in FrameApply.apply_series_generator(self)
#     904 with option_context("mode.chained_assignment", None):
#     905     for i, v in enumerate(series_gen):
#     906         # ignore SettingWithCopy here in case the user mutates
# --> 907         results[i] = self.f(v)
#     908         if isinstance(results[i], ABCSeries):
#     909             # If we have a view on v, we need to make a copy because
#     910             #  series_generator will swap out the underlying data
#     911             results[i] = results[i].copy(deep=False)
#
# Cell In[29], line 1, in <lambda>(row)
# ----> 1 all_modules['Encoded Course Information'] = all_modules.apply(lambda row: encode_course_info(model, row), axis=1)
#
# NameError: name 'encode_course_info' is not defined

# %%
all_modules['Encoded Course Name'] = all_modules.apply(lambda row: encode_course_name(model, row), axis=1)

# %%
all_modules.to_csv(os.path.join(os.getcwd(), "all_modules_with_encodings.csv"), index=False)

# %%
all_modules.tail(50)
# Out:
#      Course Code                                        Course Name  \
# 1822      AED38E                          PSYCHOPATHOLOGY IN YOUTHS
# 1823      MA0303                          HUMAN RESOURCE MANAGEMENT
# 1824      MA5105                    ENGINEERING MANAGEMENT ANALYSIS
# 1825      CM5012                   INTRODUCTION TO FORENSIC SCIENCE
# 1826      CS5207                FIFTY DISCOVERIES, FIFTY INVENTIONS
# 1827      EE5087                            LIVING WITH MATHEMATICS
# 1828      DM5001                                         WEB DESIGN
# 1829      BU5241                                FINANCIAL WELLBEING
# 1830      BU5544   MARKETING HEALTH: CONSUMERS' PURSUIT OF WELLNESS
# 1831      BU5644      SMARTER BRAIN? THE SCIENCE OF DECISION MAKING
# 1832      CS5005                 THE POWER OF MEDIA: MYTH & REALITY
# 1833      CS5211                                   HOW MUSIC SPEAKS
# 1834      CY1007                                     CLIMATE CHANGE
# 1835      CY0002                                             ETHICS
# 1836      CY1602                                     MATHEMATICS II
# 1837      BL5305                                  ADVANCED TAXATION
# 1838      DA5000                                    APPLIED DRAWING
# 1839      DA5002                      WATERMEDIA LANDSCAPE PAINTING
# 1840      DA5003  KINETIC ANATOMY:DYNAMIC FIG DRAWING FOR ARTIST...
# 1841      DA5004    DESIGN, ART, & ANIMATION FOR MEDIA ARCHITECTURE
# 1842      DA5010                           FIGURE SCULPTURE IN CLAY
# 1843      DF5002                                  CINEMATOGRAPHY II
# 1844      DT5000                                  DIGITAL SCULPTING
# 1845      DT5001                               GRAPHIC STORYTELLING
# 1846      DV5002                                   PACKAGING DESIGN
# 1847      BS1033         LABORATORY FOR FOUNDATIONS OF CHEMISTRY II
# 1848      CH5200                                  FOOD MICROBIOLOGY
# 1849      ET5214                 FINANCING ENTREPRENEURIAL VENTURES
# 1850      CH5204                         QUALITY SYSTEMS OPERATIONS
#
#                                                  Topics
# 1822  [psychopathology youths course, psychopatholog...
# 1823  [human resource management, hrm managing, fund...
# 1824  [engineering management analysis, engineering ...
# 1825  [understand forensic science, forensic science...
# 1826                                                 []
# 1827                                                 []
# 1828                                [web design course]
# 1829  [financial wellbeing course, financial wellbeing]
# 1830     [marketing health consumers, marketing health]
# 1831                                                 []
# 1832                                  [media influence]
# 1833                                                 []
# 1834                                                 []
# 1835   [ethics metaethics students, ethics course aims]
# 1836                                                 []
# 1837  [foreign income singapore, singapore tax, inco...
# 1838                                                 []
# 1839                                                 []
# 1840                              [anatomy dynamic fig]
# 1841                                                 []
# 1842                                                 []
# 1843  [cinematography ii course, prerequisite course...
# 1844                         [digital sculpting course]
# 1845  [storytelling comics course, storytelling comi...
# 1846  [packaging design basics, packaging design cou...
# 1847                             [chemistry laboratory]
# 1848  [food microbiology, introduction food microbio...
# 1849                           [funding venture course]
# 1850                                                 []
# 1851                    [chemical sustainability asian]
# 1852  [environment problems urban, urbanization sust...
# 1853                                                 []
# 1854  [eigenvectors course, eigenvalue eigenvectors ...
# 1855  [biotech business course, bio entrepreneurship...
# 1856                                                 []
# 1857  [visual arts asia, arts asia introduction, art...
# 1858  [finance art, financial markets art, financial...
# 1859                                   [ecology course]
# 1860  [multiculturalism story course, appreciating m...
# 1861             [early modern asia, asia early modern]
# 1862  [mcclosky voice method, mcclosky voice technic...
# 1863  [conducting musicianship, conducting musicians...
# 1864                                                 []
# 1865  [study nutrition relating, nutrition relating,...
# 1866  [drama education, learning theatre drama, appl...
# 1867                                                 []
# 1868                                                 []
# 1869  [tamil food festivals, culture tamil food, tam...
# 1870                           [strategies new venture]
# 1871                [food physics course, food physics]

# %%
valid_courses = all_modules_with_topics['Course Code'].tolist()

# %%
prerequisites_group_df = pd.DataFrame(columns=['course_code', 'prerequisites', 'group_id'])

# %%
mutually_exclusive_group_df = pd.DataFrame(columns=['course_code', 'mutually_exclusive'])

# %%
prereq_id = 0

# %%
for index, row in all_modules_with_topics.iterrows():
    course_code = row['Course Code']
    list_of_mutually_exclusives = row['Mutually Exclusive']
    
    if (list_of_mutually_exclusives == None or isinstance(list_of_mutually_exclusives, float) == True or list_of_mutually_exclusives == []):
        continue
        
    for mutually_exclusive in list_of_mutually_exclusives:
        if (mutually_exclusive in valid_courses):
            new_row = pd.Series([course_code, mutually_exclusive], index=['course_code', 'mutually_exclusive'])
            mutually_exclusive_group_df = mutually_exclusive_group_df.append(new_row, ignore_index=True)

# %%
for index, row in all_modules_with_topics.iterrows():
    course_code = row['Course Code']
    list_of_prerequisites = row['Prerequisites']
    course_info = row['Course Information']
    
    if (list_of_prerequisites == None or isinstance(list_of_prerequisites, float) == True or list_of_prerequisites == []):
        continue
        
    for prerequisites in list_of_prerequisites:
        piped_prerequisites = ""
        prereq_group_id = "prereq_group_" + str(prereq_id)

        for prerequisite in prerequisites:
            if (prerequisite in valid_courses):
                piped_prerequisites += prerequisite + '|'
            else:
                piped_prerequisites = ""
                break

             
        if (len(piped_prerequisites) != 0):
            piped_prerequisites = piped_prerequisites[0 : len(piped_prerequisites)-1]

            new_row = pd.Series([course_code, piped_prerequisites, prereq_group_id], index=['course_code', 'prerequisites', 'group_id'])
            prereq_id += 1

            prerequisites_group_df = prerequisites_group_df.append(new_row, ignore_index=True)

# %%
prerequisites_group_df.to_csv(os.path.join(os.getcwd(), "prerequisite_groups.csv"), index=False)

# %%
mutually_exclusive_group_df.to_csv(os.path.join(os.getcwd(), "mutually_exclusive.csv"), index=False)

# %%
def parse_topics(list_of_topics):
    
    if (list_of_topics == []):
        return None
    
    piped_list_of_topics = ""
    
    for topic in list_of_topics:
        piped_list_of_topics += topic + '|'
    
    piped_list_of_topics = piped_list_of_topics[0 : len(piped_list_of_topics)-1]
    
    return piped_list_of_topics

# %%
all_modules_with_topics['Topics'] = all_modules_with_topics['Topics'].apply(lambda x: parse_topics(x))

# %%
all_modules_with_topics.drop('Prerequisites', axis=1, inplace=True)

# %%
all_modules_with_topics.drop('Mutually Exclusive', axis=1, inplace=True)

# %%
faculty_to_topic_mapping = {
    'ASE' : 'environmental earth systems science', 'LCC' : 'communication', 'SOH' : 'humanities', 'CML' : 'languages',
    'USP' : 'premier', 'NBS' : 'business', 'ICC' : 'interdisciplinary', 'SSS' : 'social science', 'NTUpreneur' : 'entrepreneurship',
    'ADM' : 'art, design and media', 'CCEB' : 'chemistry, chemical engineering and biotech', 'SCSE' : 'computer science',
    'EEE' : 'electrical engineering', 'COE' : 'general engineering', 'MAE' : 'mechanical engineering',
    'SPMS' : 'physical and mathematical sciences', 'MSE' : 'material science', 'SBS' : 'biological science',
    'CEE' : 'civil and environmental engineering', 'WKWSCI' : 'communication studies', 'REP' : 'renaissance engineering',
    'NIE' : 'education', 'CNY' : 'cn yang program', 'LKCMedicine' : 'medicine'
}

# %%
def add_faculty_to_topic(row):
    faculty = row['Faculty']
    topics = row['Topics']
    
    if (topics == None):
        return faculty_to_topic_mapping[faculty]
    
    topics += '|' + faculty_to_topic_mapping[faculty]
    
    return topics

# %%
all_modules_with_topics['Topics'] = all_modules_with_topics.apply(lambda x: add_faculty_to_topic(x), axis=1)

# %%
all_modules_with_topics.head(10)
# Out:
#   Course Code                                   Course Name  Academic Units  \
# 0      GC0001       SUSTAINABILITY: SEEING THROUGH THE HAZE               1
# 1      HW0001        INTRODUCTION TO ACADEMIC COMMUNICATION               0
# 2      HY0001                      ETHICS & MORAL REASONING               1
# 3      LS5005                      SPANISH LANGUAGE LEVEL 5               3
# 4      SP0061             SCIENCE & TECHNOLOGY FOR HUMANITY               3
# 5      AB0403  DECISION MAKING WITH PROGRAMMING & ANALYTICS               3
# 6      AB1201                          FINANCIAL MANAGEMENT               3
# 7      AB1202                         STATISTICS & ANALYSIS               3
# 8      AB1301                                  BUSINESS LAW               3
# 9      AB1403                            INTERMEDIATE EXCEL               1
#
#   Faculty  BDE     Grade Type  \
# 0     ASE  Yes      Pass/Fail
# 1     LCC  Yes      Pass/Fail
# 2     SOH  Yes      Pass/Fail
# 3     CML  Yes  Letter Graded
# 4     USP  Yes  Letter Graded
# 5     NBS  Yes  Letter Graded
# 6     NBS  Yes  Letter Graded
# 7     NBS  Yes  Letter Graded
# 8     NBS  Yes  Letter Graded
# 9     NBS  Yes      Pass/Fail
#
#                                   Course Information  \
# 0  The course wi ll discuss sustainability from p...
# 1  The course aims to support you in your academi...
# 2  HY0001 will introduce students to three major ...
# 3  This blended learning course, based on the fli...
# 4  The course aims to inspire a long-lasting mind...
# 5  This is an introductory course designed for bu...
# 6  d Income Securities, Derivatives Securities, a...
# 7  This course introduces the concepts and method...
# 8  The aim of this course is to provide students ...
# 9  This course focuses on teaching introductory t...
#
#                                               Topics
# 0                environmental earth systems science
# 1        academic communication course|communication
# 2             teaching ethical principles|humanities
# 3                                          languages
# 4                                            premier
# 5  programming analytics introductory|making prog...
# 6  financial management course|finance course imp...
# 7                                           business
# 8                     law relating business|business
# 9  intermediate excel course|intermediate excel|e...

# %%
def fill_empty_course_info(row):
    course_name = row['Course Name']
    course_info = row['Course Information']
    
    if (isinstance(course_info, str) == False):
        course_info = course_name
        
    return course_info

# %%
all_modules_with_topics.to_csv(os.path.join(os.getcwd(), "all_modules_final.csv"), index=False)

# %%
all_modules_with_topics = pd.read_csv("all_modules_final.csv")

# %%
all_modules_with_topics['Course Information'] = all_modules_with_topics.apply(lambda row: fill_empty_course_info(row), axis=1)

# %%
all_modules_with_topics.to_csv(os.path.join(os.getcwd(), "all_modules_with_no_empty_course_info.csv"), index=False)

# %%
all_modules_with_topics.head(10)
# Out:
#   Course Code                                   Course Name  Academic Units  \
# 0      GC0001       SUSTAINABILITY: SEEING THROUGH THE HAZE               1
# 1      HW0001        INTRODUCTION TO ACADEMIC COMMUNICATION               0
# 2      HY0001                      ETHICS & MORAL REASONING               1
# 3      LS5005                      SPANISH LANGUAGE LEVEL 5               3
# 4      SP0061             SCIENCE & TECHNOLOGY FOR HUMANITY               3
# 5      AB0403  DECISION MAKING WITH PROGRAMMING & ANALYTICS               3
# 6      AB1201                          FINANCIAL MANAGEMENT               3
# 7      AB1202                         STATISTICS & ANALYSIS               3
# 8      AB1301                                  BUSINESS LAW               3
# 9      AB1403                            INTERMEDIATE EXCEL               1
#
#   Faculty  BDE     Grade Type  \
# 0     ASE  Yes      Pass/Fail
# 1     LCC  Yes      Pass/Fail
# 2     SOH  Yes      Pass/Fail
# 3     CML  Yes  Letter Graded
# 4     USP  Yes  Letter Graded
# 5     NBS  Yes  Letter Graded
# 6     NBS  Yes  Letter Graded
# 7     NBS  Yes  Letter Graded
# 8     NBS  Yes  Letter Graded
# 9     NBS  Yes      Pass/Fail
#
#                                   Course Information  \
# 0  The course wi ll discuss sustainability from p...
# 1  The course aims to support you in your academi...
# 2  HY0001 will introduce students to three major ...
# 3  This blended learning course, based on the fli...
# 4  The course aims to inspire a long-lasting mind...
# 5  This is an introductory course designed for bu...
# 6  d Income Securities, Derivatives Securities, a...
# 7  This course introduces the concepts and method...
# 8  The aim of this course is to provide students ...
# 9  This course focuses on teaching introductory t...
#
#                                               Topics  \
# 0  environmental earth systems science|sustainabi...
# 1               academic communication|communication
# 2               ethical principles|humanities|ethics
# 3                                  languages|spanish
# 4                     premier|science and technology
# 5  introductory programming|business analytics|py...
# 6  financial management course|finance course imp...
# 7                                           business
# 8                     law relating business|business
# 9  intermediate excel course|intermediate excel|e...
#
#                           Encoded Course Information  \
# 0  -0.00025134723|0.0055372017|-0.00534589|0.0387...
# 1  -0.026351945|-0.027172152|-0.0033674345|0.0146...
# 2  0.022900576|0.13961577|0.018579232|0.009028231...
# 3  -0.032442745|-0.08577821|-0.048529234|-0.00187...
# 4  0.027388476|-0.024601875|-0.015980976|-0.05301...
# 5  -0.009309238|0.00929346|-0.05696452|-0.0486138...
# 6  -0.044498052|-0.04088343|-0.05672457|-0.034641...
# 7  -0.03529743|-0.025104275|-0.04028884|0.0185293...
# 8  0.019766005|-0.04842579|0.013231385|-0.0404873...
# 9  -0.056611944|-0.03520852|-0.037055768|-0.02616...
#
#                                  Encoded Course Name
# 0  0.036235586|0.08773596|-0.022690646|0.02463894...
# 1  0.068022825|-0.008527996|-0.00739141|0.0046476...
# 2  0.01748612|0.08560437|0.03321585|0.018731872|-...
# 3  0.0024722698|-0.06658963|-0.025160616|0.032979...
# 4  0.05891931|0.030846994|-0.03908595|-0.05486637...
# 5  0.0009535659|0.09369335|-0.025330124|-0.049200...
# 6  0.009423677|0.0021888278|-0.037903763|-0.01046...
# 7  -0.01004325|-0.011976355|-0.059103694|0.011011...
# 8  0.045453105|-0.0012096729|-0.009872127|0.00814...
# 9  -0.087172076|-0.010662532|-0.029617377|-0.0419...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-mpnet-base-v2')

# #Our sentences we like to encode
# sentences = ['This framework generates embeddings for each input sentence',
#     'Sentences are passed as a list of string.',
#     'The quick brown fox jumps over the lazy dog.']

#Sentences are encoded by calling model.encode()
embeddings = model.encode('This framework generates embeddings for each input sentence')

# #Print the embeddings
# for sentence, embedding in zip(sentences, embeddings):
#     print("Sentence:", sentence)
#     print("Embedding:", embedding)
#     print("")

# %%
def encode_course_info(model, row):
    course_info = row['Course Information']
    embedding = []
    
    if (isinstance(course_info, str) == False):
        return ""
    
    embeddings = model.encode(course_info)
    
    embedding_string = ""
    
    for embedding in embeddings:
        embedding_string += str(embedding) + "|"
        
    embedding_string = embedding_string[0 : len(embedding_string)-1]
            
    return embedding_string

# %%
all_modules_with_topics['Encoded Course Information'] = all_modules_with_topics.apply(lambda row: encode_course_info(model, row), axis=1)

# %%
def encode_course_name(model, row):
    course_name = row['Course Name']
    embedding = []
    
    if (isinstance(course_name, str) == False):
        return ""
    
    embeddings = model.encode(course_name)
    
    embedding_string = ""
    
    for embedding in embeddings:
        embedding_string += str(embedding) + "|"
        
    embedding_string = embedding_string[0 : len(embedding_string)-1]
            
    return embedding_string

# %%
all_modules_with_topics['Encoded Course Name'] = all_modules_with_topics.apply(lambda row: encode_course_name(model, row), axis=1)

# %%
all_modules_with_topics.to_csv(os.path.join(os.getcwd(), "all_modules_with_encodings.csv"), index=False)
